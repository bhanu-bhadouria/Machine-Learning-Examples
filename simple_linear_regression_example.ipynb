# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanu-bhadouria/Machine-Learning-Examples/blob/main/simple_linear_regression_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simple Linear Regression**

# %% [markdown]
# **Importing imp libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing the dataset**

# %%
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[ : , : -1].values
y = dataset.iloc[ : , -1].values

# %% [markdown]
# **Spliting the dataset into training and testing set**

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split( X , y , test_size = 0.2 , random_state = 0)

# %% [markdown]
# **Training the Simple Linear Regression on the train set**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Predicting the test set results**

# %%
yhat = lr.predict(X_test)

# %% [markdown]
# **Visiualising the training set results**

# %%
plt.scatter( X_train , y_train , color = "red")
plt.plot( X_train , lr.predict(X_train) , color = "blue")
plt.title("years of explerience v/s salary")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Visiualising the test set results**

# %%
plt.scatter( X_test , y_test , color = "red")
plt.plot( X_test , yhat , color = "blue")
plt.title("years of explerience v/s salary")
plt.xlabel("years of experience")
plt.ylabel("salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
